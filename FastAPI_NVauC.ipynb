# %%
# !choco install ngrok
# Out:
# /bin/bash: line 1: choco: command not found

# %%
# !pip install streamlit
# !pip install pyngrok

# %%
# %%writefile app.py
import streamlit as st
PAGE_CONFIG =
{
    "page_title":"StColab.io", "page_icon":":smiley:", "layout":"centered"
}
def main():
  st.title("NVauC")
  st.subheader("How to run streamlit from colab")

  menu = ["Home", "About"]
  choice = st.sidebar.selectbox('Menu', menu)
  if choice == 'Home':
    st.subheader("Streamlit From Colab")

if __name__ == '__main__':
  main()
# Out:
# Overwriting app.py

# %%
# !ls
# Out:
# app.py	nohup.out  sample_data

# %%
# !nohup streamlit run app.py &
# Out:
# nohup: appending output to 'nohup.out'

# %%
import getpass
from pyngrok import ngrok, conf

print("Enter your authtoken, which can be copied from https://dashboard.ngrok.com/auth")
conf.get_default().auth_token = getpass.getpass()

# Open a TCP ngrok tunnel to the SSH server
connection_string = ngrok.connect("22", "tcp").public_url

ssh_url, port = connection_string.strip("tcp://").split(":")
print(f" * ngrok tunnel available, access with `ssh root@{ssh_url} -p{port}`")
# Out:
# Enter your authtoken, which can be copied from https://dashboard.ngrok.com/auth
# ··········
#  * ngrok tunnel available, access with `ssh root@8.tcp.ngrok.io -p13004`

# %%
# !pkill ngrok
# !pip install ngrok

# %%
import ngrok

# Set the port to tunnel to
port = 8501

# Create a tunnel to the port using HTTPS
public_url = ngrok.connect(addr=port, proto="https", name="my_streamlit_tunnel")

# Print the public URL of the tunnel
print(public_url)
# Out:
# <Task pending name='Task-1' coro=<wrap() running at ngrok_wrapper:6>>
